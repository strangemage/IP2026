# %% [markdown]
# ### HW3 Remove Perspective Distortion

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sIMG_2164.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[200,100],[800,100],[200,700],[800,700]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(300,300))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu1.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[323,282],[760,310],[323,534],[767,509]])
pts2 = np.float32([[300,300],[800,300],[300,600],[800,600]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1100,900))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu3.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[107,228],[700,160],[111,500],[710,540]])
pts2 = np.float32([[300,300],[800,300],[300,600],[800,600]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(1100,900))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('IMG_6504.jpg')
rows,cols,ch = img.shape

pts1 = np.float32([[167,184],[762,192],[100,1081],[811,1097]])
pts2 = np.float32([[0,0],[600,0],[0,900],[600,900]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(600,900))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()
