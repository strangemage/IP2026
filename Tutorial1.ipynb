# %%
tu = (23, 'abc', 4.56, (2,3), 'def')
tu[1]
# Out:
# 'abc'

# %%
li = ["abc", 34, 4.34, 23]
li[1]
# Out:
# 34

# %%
st = "Hello World"
st = 'Hello World'
st = """This is a multi-line string that uses triple quotes."""

# %%
st = "Hello World"
st[1]
# Out:
# 'e'

# %%
t = (23, 'abc', 4.56, (2,3), 'def')
t[1]
# Out:
# 'abc'

# %%
t[-3]
# Out:
# 4.56

# %%
t[1:4]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1]
# Out:
# ('abc', 4.56, (2, 3))

# %%
t[1:-1:2]
# Out:
# ('abc', (2, 3))

# %%
t[:2]
# Out:
# (23, 'abc')

# %%
t[2:]
# Out:
# (4.56, (2, 3), 'def')

# %%
t[:]
# Out:
# (23, 'abc', 4.56, (2, 3), 'def')

# %%
list1 = [1,2,3]
list2 = list1

# %%
list2
# Out:
# [1, 2, 3]

# %%
list2[1] = 999

# %%
list2
# Out:
# [1, 999, 3]

# %%
list2 = list1[:]
list2
# Out:
# [1, 2, 3]

# %%
t=[1,2,4,5]
3 in t
# Out:
# False

# %%
4 in t
# Out:
# True

# %%
4 not in t
# Out:
# False

# %%
a='abcde'
'c' in a
# Out:
# True

# %%
'cd' in a
# Out:
# True

# %%
'ac' in a

# %%
(1, 2, 3) + (4, 5, 6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
"Hello" + " " + "World"
# Out:
# 'Hello World'
