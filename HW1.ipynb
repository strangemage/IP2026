# %% [markdown]
# ### HW1
# #### trackbar, color channel, text, box selection

# %% [markdown]
# https://youtu.be/DGazy8-2fhk

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# %%
drawing = False # true if mouse is pressed
ix,iy = -1,-1
cx,cy = -1,-1
org_img = cv2.imread('mountain.jpg')
img = org_img.copy() 
# mouse callback function
def draw_circle(event,x,y,flags,param):
    global ix,iy,drawing,img,cx,cy
    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv2.EVENT_MOUSEMOVE:
        cx,cy = x,y
    elif event == cv2.EVENT_LBUTTONUP:
        ix,iy = -1,-1
        cx,cy = -1,-1
        drawing = False

# %%
cv2.namedWindow('image')
cv2.createTrackbar('value', 'image',0,255,nothing)
cv2.setMouseCallback('image',draw_circle)
font = cv2.FONT_HERSHEY_SIMPLEX


while(1) : 
    img = org_img.copy() 
    value = cv2.getTrackbarPos('value','image')
    cv2.putText(img,f"Mouse position :  ({ix},{iy}) - ({cx},{cy}) , value : {value}",(10,20), font, 0.8,(255,255,255),1,cv2.LINE_AA)
    if drawing == True:
        img[iy:cy,ix:cx,2] = 255
    cv2.imshow('image',img)    
    k = cv2.waitKey(1) & 0xFF
    if k == 27: # wait for ESC key to exit
        break
    
  


cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 9
#       7 while(1) :
#       8     img = org_img.copy()
# ----> 9     value = cv2.getTrackbarPos('value','image')
#      10     cv2.putText(img,f"Mouse position :  ({ix},{iy}) - ({cx},{cy}) , value : {value}",(10,20), font, 0.8,(255,255,255),1,cv2.LINE_AA)
#      11     if drawing == True:
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2570: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'
