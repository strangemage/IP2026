# %%
import numpy as np
import cv2

def run_main():
    cap = cv2.VideoCapture(0)

    while(True):
        ret, frame = cap.read()
        roi = frame[0:500, 0:500]
        gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)

        gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
        thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 1)

        kernel = np.ones((3, 3), np.uint8)
        closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE,
        kernel, iterations=4)

        cont_img = closing.copy()
        contours, hierarchy = cv2.findContours(cont_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        for cnt in contours:
            area = cv2.contourArea(cnt)
            if area < 2000 or area > 4000:
                continue

            if len(cnt) < 5:
                continue

            ellipse = cv2.fitEllipse(cnt)
            cv2.ellipse(roi, ellipse, (0,255,0), 2)

        cv2.imshow("Morphological Closing", closing)
        cv2.imshow("Adaptive Thresholding", thresh)
        cv2.imshow('Contours', roi)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    run_main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 44
#      41     cv2.destroyAllWindows()
#      43 if __name__ == "__main__":
# ---> 44     run_main()
#
# Cell In[4], line 8, in run_main()
#       5 cap = cv2.VideoCapture(0)
#       7 while(True):
# ----> 8     ret, frame = cap.read()
#       9     roi = frame[0:500, 0:500]
#      10     gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
#
# KeyboardInterrupt:

# %%
import numpy as np
import cv2

def run_main():
    cap = cv2.VideoCapture(0)

    if not cap.isOpened(): #ai가 추가해준 코드
        print("오류: 카메라를 열 수 없습니다.")
        return

    while(True):
        ret, frame = cap.read()
        
        # 프레임을 제대로 읽었는지 확인
        if not ret or frame is None:
            print("프레임을 읽어오지 못했습니다. 종료합니다.")
            break

        # 안전하게 ROI 설정 (카메라 해상도가 500 미만일 경우 대비)
        h, w = frame.shape[:2]
        roi_h, roi_w = min(h, 500), min(w, 500)
        roi = frame[0:roi_h, 0:roi_w]

        gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
        gray_blur = cv2.GaussianBlur(gray, (15, 15), 0)
        thresh = cv2.adaptiveThreshold(gray_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                     cv2.THRESH_BINARY_INV, 11, 1)

        kernel = np.ones((3, 3), np.uint8)
        closing = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=4)

        # OpenCV 4.x 이상에서는 findContours가 2개의 값을 반환합니다.
        contours, _ = cv2.findContours(closing, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        for cnt in contours:
            area = cv2.contourArea(cnt)
            # 면적 필터링
            if area < 2000 or area > 4000:
                continue

            # fitEllipse는 최소 5개의 점이 필요함
            if len(cnt) < 5:
                continue

            ellipse = cv2.fitEllipse(cnt)
            cv2.ellipse(roi, ellipse, (0, 255, 0), 2)

        cv2.imshow("Morphological Closing", closing)
        cv2.imshow("Adaptive Thresholding", thresh)
        cv2.imshow('Contours', roi)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    run_main()
